# %% [markdown]
# # MobileNet

# %% [markdown]
# ## Import

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds

# %% [markdown]
# ## MobileNet

# %% [markdown]
# ### Depthwise Separable Convolution

# %%
# 3x3 Depthwise
def depthwise(layer, strides=1, name=0):
    if strides == 2:
        x = keras.layers.ZeroPadding2D(((0,1), (0,1)),
                                        name=f'Depthwise_padding{name}')(layer)
    else:
        x = layer
    x = keras.layers.DepthwiseConv2D(kernel_size=(3,3),
                                     strides=strides,
                                     padding='same' if strides==1 else 'valid',
                                     use_bias=False,
                                     name=f'Depthwise_{name}')(x)
    x = keras.layers.BatchNormalization(name=f'Depthwise_batchnorm_{name}')(x)
    x = keras.layers.ReLU(6., name=f'Depthwise_relu_{name}')(x)
    return x

# %%
# 1x1 Pointwise
def pointwise(layer, channel, width_multiplier=1, strides=1, name=0):
    x = keras.layers.Conv2D(filters=int(round(channel*width_multiplier)),
                            kernel_size=(1,1),
                            strides=strides,
                            padding='same',
                            use_bias=False,
                            name=f"Pointwise_{name}")(layer)
    x = keras.layers.BatchNormalization(name=f'Pointwise_batchnorm_{name}')(x)
    x = keras.layers.ReLU(6., name=f'Pointwise_relu_{name}')(x)
    
    return x

# %% [markdown]
# ### Build MobileNet

# %%
def build_MobileNet(input_shape=(224,224,3),
                    num_strides_list=[1, 2, 1, 2, 1, 2, 1, 2, 1],
                    num_channel_list=[64, 128, 128, 256, 256, 512, 512, 1024, 1024],
                    width_multiplier = 1,
                    resolution_multiplier = 1,
                    num_classes=1000):
    input_resolution = (int(round(input_shape[0]*resolution_multiplier)))
    
    input_layer = keras.layers.Input(shape=(input_resolution, input_resolution, 3), name='Input')
    output = keras.layers.ZeroPadding2D(((0,1), (0,1)),
                                        name='First_padding')(input_layer)
    output = keras.layers.Conv2D(filters=32,
                                 kernel_size=(3,3),
                                 strides=2,
                                 padding='valid',
                                 use_bias=False,
                                 name='First_Conv_layer')(output)
    output = keras.layers.BatchNormalization(name='First_BatchNorm')(output)
    output = keras.layers.ReLU(6., name='First_Activation')(output)
    
    # Depthwise Separable Convolution
    for idx, (stride, channel) in enumerate(zip(num_strides_list, num_channel_list)):
        if idx == 6:
            for j in range(5):
                output = depthwise(output, strides= stride, name=f'{idx}_{j}')
                output = pointwise(output, channel, width_multiplier, name=f'{idx}_{j}')
        else:
            output = depthwise(output, strides= stride, name=idx)
            output = pointwise(output, channel, width_multiplier, name=idx)
    
    
    output = keras.layers.GlobalAveragePooling2D(name='GAP')(output)
    output = keras.layers.Dropout(0.001, name='Dropout')(output)
    output = keras.layers.Dense(num_classes, activation='softmax', name='Classifier')(output)
    
    model = keras.Model(inputs=input_layer, outputs=output)
    
    return model

# %%
MobileNet = build_MobileNet()
MobileNet.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 224, 224, 3)]     0
# _________________________________________________________________
# First_padding (ZeroPadding2D (None, 225, 225, 3)       0
# _________________________________________________________________
# First_Conv_layer (Conv2D)    (None, 112, 112, 32)      864
# _________________________________________________________________
# First_BatchNorm (BatchNormal (None, 112, 112, 32)      128
# _________________________________________________________________
# First_Activation (ReLU)      (None, 112, 112, 32)      0
# _________________________________________________________________
# Depthwise_0 (DepthwiseConv2D (None, 112, 112, 32)      288
# _________________________________________________________________
# Depthwise_batchnorm_0 (Batch (None, 112, 112, 32)      128
# _________________________________________________________________
# Depthwise_relu_0 (ReLU)      (None, 112, 112, 32)      0
# _________________________________________________________________
# Pointwise_0 (Conv2D)         (None, 112, 112, 64)      2048
# _________________________________________________________________
# Pointwise_batchnorm_0 (Batch (None, 112, 112, 64)      256
# _________________________________________________________________
# Pointwise_relu_0 (ReLU)      (None, 112, 112, 64)      0
# _________________________________________________________________
# Depthwise_padding1 (ZeroPadd (None, 113, 113, 64)      0
# _________________________________________________________________
# Depthwise_1 (DepthwiseConv2D (None, 56, 56, 64)        576
# _________________________________________________________________
# Depthwise_batchnorm_1 (Batch (None, 56, 56, 64)        256
# _________________________________________________________________
# Depthwise_relu_1 (ReLU)      (None, 56, 56, 64)        0
# _________________________________________________________________
# Pointwise_1 (Conv2D)         (None, 56, 56, 128)       8192
# _________________________________________________________________
# Pointwise_batchnorm_1 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# Pointwise_relu_1 (ReLU)      (None, 56, 56, 128)       0
# _________________________________________________________________
# Depthwise_2 (DepthwiseConv2D (None, 56, 56, 128)       1152
# _________________________________________________________________
# Depthwise_batchnorm_2 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# Depthwise_relu_2 (ReLU)      (None, 56, 56, 128)       0
# _________________________________________________________________
# Pointwise_2 (Conv2D)         (None, 56, 56, 128)       16384
# _________________________________________________________________
# Pointwise_batchnorm_2 (Batch (None, 56, 56, 128)       512
# _________________________________________________________________
# Pointwise_relu_2 (ReLU)      (None, 56, 56, 128)       0
# _________________________________________________________________
# Depthwise_padding3 (ZeroPadd (None, 57, 57, 128)       0
# _________________________________________________________________
# Depthwise_3 (DepthwiseConv2D (None, 28, 28, 128)       1152
# _________________________________________________________________
# Depthwise_batchnorm_3 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# Depthwise_relu_3 (ReLU)      (None, 28, 28, 128)       0
# _________________________________________________________________
# Pointwise_3 (Conv2D)         (None, 28, 28, 256)       32768
# _________________________________________________________________
# Pointwise_batchnorm_3 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# Pointwise_relu_3 (ReLU)      (None, 28, 28, 256)       0
# _________________________________________________________________
# Depthwise_4 (DepthwiseConv2D (None, 28, 28, 256)       2304
# _________________________________________________________________
# Depthwise_batchnorm_4 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# Depthwise_relu_4 (ReLU)      (None, 28, 28, 256)       0
# _________________________________________________________________
# Pointwise_4 (Conv2D)         (None, 28, 28, 256)       65536
# _________________________________________________________________
# Pointwise_batchnorm_4 (Batch (None, 28, 28, 256)       1024
# _________________________________________________________________
# Pointwise_relu_4 (ReLU)      (None, 28, 28, 256)       0
# _________________________________________________________________
# Depthwise_padding5 (ZeroPadd (None, 29, 29, 256)       0
# _________________________________________________________________
# Depthwise_5 (DepthwiseConv2D (None, 14, 14, 256)       2304
# _________________________________________________________________
# Depthwise_batchnorm_5 (Batch (None, 14, 14, 256)       1024
# _________________________________________________________________
# Depthwise_relu_5 (ReLU)      (None, 14, 14, 256)       0
# _________________________________________________________________
# Pointwise_5 (Conv2D)         (None, 14, 14, 512)       131072
# _________________________________________________________________
# Pointwise_batchnorm_5 (Batch (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_5 (ReLU)      (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_6_0 (DepthwiseConv (None, 14, 14, 512)       4608
# _________________________________________________________________
# Depthwise_batchnorm_6_0 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Depthwise_relu_6_0 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Pointwise_6_0 (Conv2D)       (None, 14, 14, 512)       262144
# _________________________________________________________________
# Pointwise_batchnorm_6_0 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_6_0 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_6_1 (DepthwiseConv (None, 14, 14, 512)       4608
# _________________________________________________________________
# Depthwise_batchnorm_6_1 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Depthwise_relu_6_1 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Pointwise_6_1 (Conv2D)       (None, 14, 14, 512)       262144
# _________________________________________________________________
# Pointwise_batchnorm_6_1 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_6_1 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_6_2 (DepthwiseConv (None, 14, 14, 512)       4608
# _________________________________________________________________
# Depthwise_batchnorm_6_2 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Depthwise_relu_6_2 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Pointwise_6_2 (Conv2D)       (None, 14, 14, 512)       262144
# _________________________________________________________________
# Pointwise_batchnorm_6_2 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_6_2 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_6_3 (DepthwiseConv (None, 14, 14, 512)       4608
# _________________________________________________________________
# Depthwise_batchnorm_6_3 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Depthwise_relu_6_3 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Pointwise_6_3 (Conv2D)       (None, 14, 14, 512)       262144
# _________________________________________________________________
# Pointwise_batchnorm_6_3 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_6_3 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_6_4 (DepthwiseConv (None, 14, 14, 512)       4608
# _________________________________________________________________
# Depthwise_batchnorm_6_4 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Depthwise_relu_6_4 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Pointwise_6_4 (Conv2D)       (None, 14, 14, 512)       262144
# _________________________________________________________________
# Pointwise_batchnorm_6_4 (Bat (None, 14, 14, 512)       2048
# _________________________________________________________________
# Pointwise_relu_6_4 (ReLU)    (None, 14, 14, 512)       0
# _________________________________________________________________
# Depthwise_padding7 (ZeroPadd (None, 15, 15, 512)       0
# _________________________________________________________________
# Depthwise_7 (DepthwiseConv2D (None, 7, 7, 512)         4608
# _________________________________________________________________
# Depthwise_batchnorm_7 (Batch (None, 7, 7, 512)         2048
# _________________________________________________________________
# Depthwise_relu_7 (ReLU)      (None, 7, 7, 512)         0
# _________________________________________________________________
# Pointwise_7 (Conv2D)         (None, 7, 7, 1024)        524288
# _________________________________________________________________
# Pointwise_batchnorm_7 (Batch (None, 7, 7, 1024)        4096
# _________________________________________________________________
# Pointwise_relu_7 (ReLU)      (None, 7, 7, 1024)        0
# _________________________________________________________________
# Depthwise_8 (DepthwiseConv2D (None, 7, 7, 1024)        9216
# _________________________________________________________________
# Depthwise_batchnorm_8 (Batch (None, 7, 7, 1024)        4096
# _________________________________________________________________
# Depthwise_relu_8 (ReLU)      (None, 7, 7, 1024)        0
# _________________________________________________________________
# Pointwise_8 (Conv2D)         (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# Pointwise_batchnorm_8 (Batch (None, 7, 7, 1024)        4096
# _________________________________________________________________
# Pointwise_relu_8 (ReLU)      (None, 7, 7, 1024)        0
# _________________________________________________________________
# GAP (GlobalAveragePooling2D) (None, 1024)              0
# _________________________________________________________________
# Dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# Classifier (Dense)           (None, 1000)              1025000
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________
